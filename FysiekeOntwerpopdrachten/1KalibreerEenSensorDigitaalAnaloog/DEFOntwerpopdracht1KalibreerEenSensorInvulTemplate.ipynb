# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
# Aan het einde van deze ontwerpopdracht lever je als groep dit notebook gezamenlijk in via een pull request op Github en lever je een link naar dit pull request in op Brightspace. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan. Werk in de juiste branch.
#
# | Groep: 18     |  |
# | :-------------|:-------------|
# | Aren Meghdadi| 6474349 |
# | Zenn Idu| 6225497 |
# | Juraj Hadak| 5989779 |
#
# | Planning Groep: 18    |Tijdstip / Tijdspanne  |
# |---|---|
# | Mijlpaal 1: Criteria opgesteld | 12:45 |
# | Mijlpaal 2: Eerste kalibratie meting gedaan| 15:00 |
# | Pauze 1| 12:30-13:30 |
# | Pauze 2| 14:30-14:45 |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
#
# Zet de foto in dezelfde map als dit notebook en verander hieronder de naam in de naam van de foto.
#
# ![Alt](schetsen_opd1_foto.jpeg "analyse: ideeen")

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |LDR | Een lichtsensor die bij een bepaalde waarde (wanneer het te donker is) een lamp aanzet (bijvoorbeeld voor een straatlamp) | De waarde waar de LED lamp aan gaat is vanaf 10 lux met een nauwkeurigheid van 1 lux. |
# | | |Voor het bepalen van deze waarden wordt het gemiddelde genomen van de metingen in de afgelopen 10 minuten. |
# |||Ook wordt het gemiddelde genomen van meerdere lichtsensoren op verschillende plaatsen om de waarde voor een gebied van 5 m^2 te bepalen. |
# |||De lichtsensor moet kunnen meten tussen 0.01 en 1000 lux (van een donkere, maanloze nacht tot overdag fel zonlicht). |
# |||De lichtsensor meet elke minuut en het datapunt wordt automatisch in een tabel genoteerd. |
# |Thermistor | Een thermistor die de buitentemperatuur meet en vanaf een bepaalde waarde een LED lamp aanzet die aangeeft dat je een jas aan moet naar buiten. | De waarde waarbij de LED lamp aan gaat is onder 10 graden Celsius. |
# |||Moet kunnen meten tussen -10 en 30 graden met 1 graad nauwkeurigheid. |
# |||Moet bij 10 graden een signaal sturen om de LED lamp aan te zetten. |
# |||De waarde volgt uit het gemiddelde van de temperaturen in de afgelopen 3 minuten. |
# |||Wanneer het apparaat aan staat meet het elke 10 seconden en noteert het datapunt in een tabel. |
# |Hall sensor| Bepalen van de RPM van een roterend wiel waar een magneet aan verbonden is. | De magneet moet minder wegen dan 5% van het gewicht van het wiel. |
# |||De magneet op het wiel moet een sterkte hebben van 5 mT en moet meetbaar zijn op een afstand van 30 cm. |
# |||De sensor moet kunnen worden geplaatst onder de bagagedrager van de fiets. |
# |||De sensor moet wanneer de magneet langsdraait noteren dat het iets heeft gemeten, de specifieke waarde maakt niet uit.|
# ||| De nauwkeurigheid in de meting moet 0.5 mT zijn. |
#
#
# Groep 18 heeft gekozen voor sensor thermistor.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# Licht kort toe wat er in de foto te zien is.
#  ![Alt](schakeling_schets.jpeg "schets student")
#  ![Alt](schets_opstelling.jpeg "schets student")
#
#  De eerste foto geeft twee schakelingen weer, de linker is de schakeling van de thermistor en de rechter is de schakeling van de LED.
#  De tweede foto geeft weer hoe de meting wordt gedaan, een thermometer (rechts) wordt dichtbij de thermistor gehouden en de temperatuur van de lucht wordt tegelijk in bits en in Celsius gemeten.

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# 1. Welke variabelen ga je veranderen? \
# We veranderen de temperatuur van de lucht.
# 2. Over welk bereik ga je deze variabelen veranderen?\
# Van 0 graden Celsius tot 35 graden Celsius.
# 3. Wat ga je allemaal meten?\
# Temperaturen van lucht rond: -10, -5, 0, 5, 10, 15, 20, 25, 30, 35 graden Celsius.
# 4. Hoeveel metingen ga je doen?\
# 10 metingen.
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?\
# Ja, we kunnen bepalen of de sensor op het juiste bereik kan meten en of het voldoet aan de nauwkeurigheid om de waarde aan te geven.

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
#  ![Alt](opdr1_opstelling.jpeg "meetopstelling student")
#
#   Aparte schakelingen van LED lampje en thermistor met thermistor in zakje om te beschermen van water (bij bijvoorbeeld de meting in het ijs). Schakeling van LED lampje met 220 ohm weerstand en schakeling met thermistor met 10 kOhm weerstand.

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

T_bits = np.array([259, 329, 463, 527, 594, 626]) # gemeten temperatuur in bits op arduino
T_C = np.array([0.9, 7, 20.7, 25.3, 30.9, 35.3]) # gemeten temperatuur in celsius
u_bits = 2
u_C = 0.2

# %%
# Plot hier de meting en fit een lijn door de metingen.
# Maak gebruik van wat je geleerd hebt bij het practicum.
# %matplotlib inline

def functie(x, a, b): # lineair verband van meetpunten aantonen
    return a*x + b

popt, pcov = curve_fit(functie, T_bits, T_C)
bits_test = np.linspace(200, 700, 1000)
C_test = functie(bits_test, *popt)

plt.figure()
plt.errorbar(T_bits, T_C, xerr = u_bits, yerr = u_C, fmt='k.', label='measurements')
plt.plot(bits_test, C_test, 'r--', label='fit')
plt.xlabel('Meetwaarde (bits)')
plt.ylabel('$T$ (C)')
plt.legend()
plt.show()

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# Het lineaire verband is duidelijk te zien en het ontwerp voldoet aan de criteria, dus wij hebben besloten om niet te itereren.

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# De ontworpen sensor is geschikt om de echte buitentemperatuur te bepalen en geeft een lineair verband weer. De meting is nauwkeurig genoeg om het LED lampje te laten branden bij 10 graden Celsius. Er is geen automatisme of gemiddelde berekening in de code aangebracht, maar dit is wel mogelijk uit te voeren. Er was niks onder 0 graden Celsius om te meten, dus er is nog niet voor extreme kou getest.

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing
#
# Om aan te tonen dat je de leerdoelen beheerst, kopieer je hieronder alle cellen met 'leerdoel' in de titel. Zet zelf de cellen onder de goede kopjes. Mogelijk komt een cel bij meerdere leerdoelen terug.

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# Kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 1 beheersen.
#
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# Licht kort toe wat er in de foto te zien is.
#  ![Alt](schakeling_schets.jpeg "schets student")
#  ![Alt](schets_opstelling.jpeg "schets student")
#
#  De eerste foto geeft twee schakelingen weer, de linker is de schakeling van de thermistor en de rechter is de schakeling van de LED.
#  De tweede foto geeft weer hoe de meting wordt gedaan, een thermometer (rechts) wordt dichtbij de thermistor gehouden en de temperatuur van de lucht wordt tegelijk in bits en in Celsius gemeten.
#
#  ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
#  ![Alt](opdr1_opstelling.jpeg "meetopstelling student")
#
#   Aparte schakelingen van LED lampje en thermistor met thermistor in zakje om te beschermen van water (bij bijvoorbeeld de meting in het ijs). Schakeling van LED lampje met 220 ohm weerstand en schakeling met thermistor met 10 kOhm weerstand.

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# Kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 2 beheersen.
#
# ## *Opdracht 1*: Foto van alle schetsen.
#
# Zet de foto in dezelfde map als dit notebook en verander hieronder de naam in de naam van de foto.
#
# ![Alt](schetsen_opd1_foto.jpeg "analyse: ideeen")
#
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |LDR | Een lichtsensor die bij een bepaalde waarde (wanneer het te donker is) een lamp aanzet (bijvoorbeeld voor een straatlamp) | De waarde waar de LED lamp aan gaat is vanaf 10 lux met een nauwkeurigheid van 1 lux. |
# | | |Voor het bepalen van deze waarden wordt het gemiddelde genomen van de metingen in de afgelopen 10 minuten. |
# |||Ook wordt het gemiddelde genomen van meerdere lichtsensoren op verschillende plaatsen om de waarde voor een gebied van 5 m^2 te bepalen. |
# |||De lichtsensor moet kunnen meten tussen 0.01 en 1000 lux (van een donkere, maanloze nacht tot overdag fel zonlicht). |
# |||De lichtsensor meet elke minuut en het datapunt wordt automatisch in een tabel genoteerd. |
# |Thermistor | Een thermistor die de buitentemperatuur meet en vanaf een bepaalde waarde een LED lamp aanzet die aangeeft dat je een jas aan moet naar buiten. | De waarde waarbij de LED lamp aan gaat is onder 10 graden Celsius. |
# |||Moet kunnen meten tussen -10 en 30 graden met 1 graad nauwkeurigheid. |
# |||Moet bij 10 graden een signaal sturen om de LED lamp aan te zetten. |
# |||De waarde volgt uit het gemiddelde van de temperaturen in de afgelopen 3 minuten. |
# |||Wanneer het apparaat aan staat meet het elke 10 seconden en noteert het datapunt in een tabel. |
# |Hall sensor| Bepalen van de RPM van een roterend wiel waar een magneet aan verbonden is. | De magneet moet minder wegen dan 5% van het gewicht van het wiel. |
# |||De magneet op het wiel moet een sterkte hebben van 5 mT en moet meetbaar zijn op een afstand van 30 cm. |
# |||De sensor moet kunnen worden geplaatst onder de bagagedrager van de fiets. |
# |||De sensor moet wanneer de magneet langsdraait noteren dat het iets heeft gemeten, de specifieke waarde maakt niet uit.|
# ||| De nauwkeurigheid in de meting moet 0.5 mT zijn. |
#
#
# Groep 18 heeft gekozen voor sensor thermistor.
#
# ## *Opdracht 4*: Beantwoord de vragen
#
# 1. Welke variabelen ga je veranderen? \
# We veranderen de temperatuur van de lucht.
# 2. Over welk bereik ga je deze variabelen veranderen?\
# Van 0 graden Celsius tot 35 graden Celsius.
# 3. Wat ga je allemaal meten?\
# Temperaturen van lucht rond: -10, -5, 0, 5, 10, 15, 20, 25, 30, 35 graden Celsius.
# 4. Hoeveel metingen ga je doen?\
# 10 metingen.
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?\
# Ja, we kunnen bepalen of de sensor op het juiste bereik kan meten en of het voldoet aan de nauwkeurigheid om de waarde aan te geven.

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

T_bits = np.array([259, 329, 463, 527, 594, 626]) # gemeten temperatuur in bits op arduino
T_C = np.array([0.9, 7, 20.7, 25.3, 30.9, 35.3]) # gemeten temperatuur in celsius
u_bits = 2
u_C = 0.2

# %%
# Plot hier de meting en fit een lijn door de metingen.
# Maak gebruik van wat je geleerd hebt bij het practicum.
# %matplotlib inline

def functie(x, a, b): # lineair verband van meetpunten aantonen
    return a*x + b

popt, pcov = curve_fit(functie, T_bits, T_C)
bits_test = np.linspace(200, 700, 1000)
C_test = functie(bits_test, *popt)

plt.figure()
plt.errorbar(T_bits, T_C, xerr = u_bits, yerr = u_C, fmt='k.', label='measurements')
plt.plot(bits_test, C_test, 'r--', label='fit')
plt.xlabel('meetwaarde (bits)')
plt.ylabel('$T$ (C)')
plt.legend()
plt.show()

# %% [markdown]
# Kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 3 beheersen.
# (Hieronder + hierboven)
#
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
#  ![Alt](opdr1_opstelling.jpeg "meetopstelling student")
#
#   Aparte schakelingen van LED lampje en thermistor met thermistor in zakje om te beschermen van water (bij bijvoorbeeld de meting in het ijs). Schakeling van LED lampje met 220 ohm weerstand en schakeling met thermistor met 10 kOhm weerstand. Thermometer dichtbij thermistor is zichtbaar rechtsboven in de afbeelding.
#
#
# ## *Opdracht 8*: Conclusie, leerdoel
#
# De ontworpen sensor is geschikt om de echte buitentemperatuur te bepalen en geeft een lineair verband weer. De meting is nauwkeurig genoeg om het LED lampje te laten branden bij 10 graden Celsius. Er is geen automatisme of gemiddelde berekening in de code aangebracht, maar dit is wel mogelijk uit te voeren. Er was niks onder 0 graden Celsius om te meten, dus er is nog niet voor extreme kou getest.
